# %% [markdown]
# ### Simplificação da rede viária
#
# Resultado esperado:
# - Geometria simplificada com o uso da biblioteca neatnet.neatify
# - GeoPackage/GeoParquet com a nova geometria

# %%
# Instala dependencias
# %pip install geopandas pyogrio shapely neatnet
# Out:
# Requirement already satisfied: geopandas in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (1.0.1)
# Requirement already satisfied: pyogrio in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (0.10.0)
# Requirement already satisfied: shapely in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (2.1.0)
# Collecting neatnet
#   Downloading neatnet-0.1.6-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: numpy>=1.22 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from geopandas) (2.2.4)
# Requirement already satisfied: packaging in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: certifi in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from pyogrio) (2025.1.31)
# Collecting esda>=2.6.0 (from neatnet)
#   Downloading esda-2.10.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting libpysal>=4.12.1 (from neatnet)
#   Downloading libpysal-4.15.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting momepy>=0.9.0 (from neatnet)
#   Downloading momepy-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: networkx>=3.3 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from neatnet) (3.4.2)
# Requirement already satisfied: scipy>=1.14.1 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from neatnet) (1.17.1)
# Collecting scikit-learn>=1.2.0 (from neatnet)
#   Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting pandas>=1.4.0 (from geopandas)
#   Downloading pandas-3.0.5-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: beautifulsoup4>=4.13.0 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from libpysal>=4.12.1->neatnet) (4.13.5)
# Collecting geopandas
#   Using cached geopandas-1.1.4-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jinja2 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from libpysal>=4.12.1->neatnet) (3.1.6)
# Requirement already satisfied: platformdirs>=4.3 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from libpysal>=4.12.1->neatnet) (4.4.0)
# Requirement already satisfied: requests>=2.32.0 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from libpysal>=4.12.1->neatnet) (2.32.3)
# Collecting tqdm>=4.67 (from momepy>=0.9.0->neatnet)
#   Downloading tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Collecting joblib>=1.4.0 (from scikit-learn>=1.2.0->neatnet)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn>=1.2.0->neatnet)
#   Downloading narwhals-2.24.0-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn>=1.2.0->neatnet)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.13.0->libpysal>=4.12.1->neatnet) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.13.0->libpysal>=4.12.1->neatnet) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.32.0->libpysal>=4.12.1->neatnet) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.32.0->libpysal>=4.12.1->neatnet) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.32.0->libpysal>=4.12.1->neatnet) (2.4.0)
# Requirement already satisfied: colorama in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.67->momepy>=0.9.0->neatnet) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\simone\appdata\local\programs\python\python313\lib\site-packages (from jinja2->libpysal>=4.12.1->neatnet) (3.0.2)
# Downloading neatnet-0.1.6-py3-none-any.whl (146 kB)
# Downloading esda-2.10.0-py3-none-any.whl (247 kB)
# Downloading libpysal-4.15.0-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------------------- ------------------- 1.3/2.5 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 5.8 MB/s eta 0:00:00
# Using cached geopandas-1.1.4-py3-none-any.whl (343 kB)
# Downloading momepy-1.0.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------ --------- 1.3/1.7 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 5.6 MB/s eta 0:00:00
# Downloading pandas-3.0.5-cp313-cp313-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.8 MB 5.9 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.8 MB 5.9 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.8 MB 5.9 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.8 MB 5.9 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.8 MB 5.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.8 MB 5.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.8 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 5.8 MB/s eta 0:00:00
# Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.2 MB 6.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.2 MB 5.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.7/8.2 MB 5.9 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.2 MB 5.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.2 MB 5.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.2 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 5.8 MB/s eta 0:00:00
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading narwhals-2.24.0-py3-none-any.whl (461 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tqdm-4.70.0-py3-none-any.whl (80 kB)
# Installing collected packages: tqdm, threadpoolctl, narwhals, joblib, scikit-learn, pandas, geopandas, libpysal, momepy, esda, neatnet
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 1.0.1
#     Uninstalling geopandas-1.0.1:
#       Successfully uninstalled geopandas-1.0.1
# Successfully installed esda-2.10.0 geopandas-1.1.4 joblib-1.5.3 libpysal-4.15.0 momepy-1.0.0 narwhals-2.24.0 neatnet-0.1.6 pandas-3.0.5 scikit-learn-1.9.0 threadpoolctl-3.6.0 tqdm-4.70.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Simone\AppData\Local\Programs\Python\Python313\Lib\site-packages\~andas.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Simone\AppData\Local\Programs\Python\Python313\Lib\site-packages\~andas'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 25.0.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Bibliotecas 
import geopandas as gpd
import pyogrio as ogr
import shapely as shp
import neatnet
import pathlib
import matplotlib.pyplot as plt

# %matplotlib inline
